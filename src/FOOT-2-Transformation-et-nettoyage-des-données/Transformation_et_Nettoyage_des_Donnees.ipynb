# %% [markdown]
# ### Importation des données des joueurs et des matchs avec Pandas

# %%
import pandas as pd
players = "../../data/raw_data/players.csv"
matches = "../../data/raw_data/matches.csv"

players_df = pd.read_csv(players)
matches_df = pd.read_csv(matches)

# %% [markdown]
# ### Détection et suppression des doublons dans le DataFrame des joueurs et des matches

# %%
players_df[players_df.duplicated()]
players_df.drop_duplicates(inplace=True)

# %%
matches_df[matches_df.duplicated()]
matches_df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Suppression des lignes entièrement vides dans le DataFrame des joueurs et des matches

# %%
players_df[players_df.drop(columns=['Team', 'Player']).isnull().all(axis=1)]
players_df = players_df[~players_df.drop(columns=['Team', 'Player']).isnull().all(axis=1)]

# %%
matches_df[matches_df.drop(columns=['Team', 'Date']).isnull().all(axis=1)]
matches_df = matches_df[~matches_df.drop(columns=['Team', 'Date']).isnull().all(axis=1)]

# %%
players_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 702 entries, 0 to 753
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Team    702 non-null    object
#  1   Player  702 non-null    object
#  2   Nation  696 non-null    object
#  3   Pos     702 non-null    object
#  4   Age     697 non-null    float64
#  5   MP      702 non-null    float64
#  6   Starts  702 non-null    float64
#  7   Min     574 non-null    object
#  8   90s     574 non-null    float64
#  9   Gls     574 non-null    float64
#  10  Ast     574 non-null    float64
#  11  G+A     574 non-null    float64
#  12  G-PK    574 non-null    float64
#  13  PK      574 non-null    float64
#  14  PKatt   574 non-null    float64
#  15  CrdY    574 non-null    float64
#  16  CrdR    574 non-null    float64
#  17  xG      574 non-null    float64
# dtypes: float64(13), object(5)
# memory usage: 104.2+ KB

# %% [markdown]
# ### Inspection du DataFrame des  et des joueurs et nettoyage des noms de colonnes

# %%
matches_df.info()
matches_df.columns = matches_df.columns.str.strip().str.replace(" ", "_").str.lower()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 975 entries, 0 to 1003
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   team           975 non-null    object
#  1   date           975 non-null    object
#  2   time           975 non-null    object
#  3   comp           975 non-null    object
#  4   round          975 non-null    object
#  5   day            975 non-null    object
#  6   venue          975 non-null    object
#  7   result         975 non-null    object
#  8   gf             975 non-null    object
#  9   ga             975 non-null    object
#  10  opponent       975 non-null    object
#  11  xg             849 non-null    float64
#  12  xga            849 non-null    float64
#  13  poss           953 non-null    float64
#  14  attendance     969 non-null    object
#  15  captain        975 non-null    object
#  16  formation      975 non-null    object
# ...

# %%
matches_df["date"] = pd.to_datetime(matches_df["date"])
matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 975 entries, 0 to 1003
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   team           975 non-null    object
#  1   date           975 non-null    datetime64[ns]
#  2   time           975 non-null    object
#  3   comp           975 non-null    object
#  4   round          975 non-null    object
#  5   day            975 non-null    object
#  6   venue          975 non-null    object
#  7   result         975 non-null    object
#  8   gf             975 non-null    object
#  9   ga             975 non-null    object
#  10  opponent       975 non-null    object
#  11  xg             849 non-null    float64
#  12  xga            849 non-null    float64
#  13  poss           953 non-null    float64
#  14  attendance     969 non-null    object
#  15  captain        975 non-null    object
#  16  formation      975 non-null    object
# ...

# %%
matches_df['time'] = matches_df['time'].str.split(' ').str[0]
matches_df['gf'] = matches_df['gf'].str.split(' ').str[0]
matches_df['ga'] = matches_df['ga'].str.split(' ').str[0]
matches_df.head(30)
# Out:
#          team       date   time            comp               round  day  \
# 0   Liverpool 2024-08-17  12:30  Premier League         Matchweek 1  Sat
# 1   Liverpool 2024-08-25  16:30  Premier League         Matchweek 2  Sun
# 2   Liverpool 2024-09-01  16:00  Premier League         Matchweek 3  Sun
# 3   Liverpool 2024-09-14  15:00  Premier League         Matchweek 4  Sat
# 4   Liverpool 2024-09-17  21:00    Champions Lg        League phase  Tue
# 5   Liverpool 2024-09-21  15:00  Premier League         Matchweek 5  Sat
# 6   Liverpool 2024-09-25  20:00         EFL Cup         Third round  Wed
# 7   Liverpool 2024-09-28  17:30  Premier League         Matchweek 6  Sat
# 8   Liverpool 2024-10-02  20:00    Champions Lg        League phase  Wed
# 9   Liverpool 2024-10-05  12:30  Premier League         Matchweek 7  Sat
# 10  Liverpool 2024-10-20  16:30  Premier League         Matchweek 8  Sun
# 11  Liverpool 2024-10-23  21:00    Champions Lg        League phase  Wed
# ...

# %%
matches_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 975 entries, 0 to 1003
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   team           975 non-null    object
#  1   date           975 non-null    datetime64[ns]
#  2   time           975 non-null    object
#  3   comp           975 non-null    object
#  4   round          975 non-null    object
#  5   day            975 non-null    object
#  6   venue          975 non-null    object
#  7   result         975 non-null    object
#  8   gf             975 non-null    object
#  9   ga             975 non-null    object
#  10  opponent       975 non-null    object
#  11  xg             849 non-null    float64
#  12  xga            849 non-null    float64
#  13  poss           953 non-null    float64
#  14  attendance     969 non-null    object
#  15  captain        975 non-null    object
#  16  formation      975 non-null    object
# ...

# %% [markdown]
# ### Exportation des DataFrames nettoyés vers des fichiers CSV

# %%
players_df.to_csv("../../data/processed_data/players.csv",index=False)
matches_df.to_csv("../../data/processed_data/matches.csv",index=False)
